# %%
pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\sowhambhuin\appdata\local\programs\python\python312\lib\site-packages (0.2.36)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\sowhambhuin\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (2.2.0)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\sowhambhuin\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in c:\users\sowhambhuin\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\sowhambhuin\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\sowhambhuin\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (5.1.0)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\sowhambhuin\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in c:\users\sowhambhuin\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\sowhambhuin\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (2.4.0)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\sowhambhuin\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (3.17.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\sowhambhuin\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in c:\users\sowhambhuin\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\sowhambhuin\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in c:\users\sowhambhuin\appdata\local\programs\python\python312\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\sowhambhuin\appdata\local\programs\python\python312\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sowhambhuin\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sowhambhuin\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.3.0->yfinance) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sowhambhuin\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sowhambhuin\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->yfinance) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sowhambhuin\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->yfinance) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sowhambhuin\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->yfinance) (2024.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf
import pandas as pd
import numpy as np


ticker_data1 = yf.Ticker('GOOG')
ticker_data2 = yf.Ticker('MSFT')

# %%
import datetime as dt
from datetime import date, timedelta
today = date.today()
d1= today.strftime("%Y-%m-%d")
d2 = (today - timedelta(days=365)).strftime("%Y-%m-%d")
start_date=d2
end_date=d1

# %%
tickerDf1 = ticker_data1.history(period='1d', start='2018-01-01', end=end_date)
tickerDf2 = ticker_data2.history(period='1d', start='2018-01-01', end=end_date)
# Out:
# c:\Users\SowhamBhuin\AppData\Local\Programs\Python\Python312\Lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# c:\Users\SowhamBhuin\AppData\Local\Programs\Python\Python312\Lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')

# %%
tickerDf1['Close'].plot(title="google's stock price" , color='red')

tickerDf2['Close'].plot(title="Microsoft's stock price")
# Out:
# <Axes: title={'center': "Microsoft's stock price"}, xlabel='Date'>

# %%
tickerDf1.head()
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2018-01-02 00:00:00-05:00  52.417000  53.347000  52.261501  53.250000
# 2018-01-03 00:00:00-05:00  53.215500  54.314499  53.160500  54.124001
# 2018-01-04 00:00:00-05:00  54.400002  54.678501  54.200100  54.320000
# 2018-01-05 00:00:00-05:00  54.700001  55.212502  54.599998  55.111500
# 2018-01-08 00:00:00-05:00  55.111500  55.563499  55.081001  55.347000
#
#                              Volume  Dividends  Stock Splits
# Date
# 2018-01-02 00:00:00-05:00  24752000        0.0           0.0
# 2018-01-03 00:00:00-05:00  28604000        0.0           0.0
# 2018-01-04 00:00:00-05:00  20092000        0.0           0.0
# 2018-01-05 00:00:00-05:00  25582000        0.0           0.0
# 2018-01-08 00:00:00-05:00  20952000        0.0           0.0

# %%
tickerDf2.tail()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-02-13 00:00:00-05:00  404.192550  409.313085  402.645423  405.570007
# 2024-02-14 00:00:00-05:00  408.070007  409.839996  404.570007  409.489990
# 2024-02-15 00:00:00-05:00  408.140015  409.130005  404.290009  406.559998
# 2024-02-16 00:00:00-05:00  407.959991  408.290009  403.440002  404.059998
# 2024-02-20 00:00:00-05:00  403.239990  404.489990  398.010010  402.790009
#
#                              Volume  Dividends  Stock Splits
# Date
# 2024-02-13 00:00:00-05:00  27824900       0.00           0.0
# 2024-02-14 00:00:00-05:00  20401200       0.75           0.0
# 2024-02-15 00:00:00-05:00  21825500       0.00           0.0
# 2024-02-16 00:00:00-05:00  22281100       0.00           0.0
# 2024-02-20 00:00:00-05:00  24278300       0.00           0.0

# %%
tickerDf1.to_csv('google.csv')
